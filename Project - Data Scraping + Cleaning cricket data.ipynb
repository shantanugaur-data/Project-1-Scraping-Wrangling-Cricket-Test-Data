# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.espncricinfo.com/records/highest-career-batting-average-282910'

page = requests.get(url)

soup1 = BeautifulSoup(page.text,'html')

soup = BeautifulSoup(soup1.prettify(), 'html')

# %%
<div class="ds-grow" style="width:calc(100% - 322px)"><h1 class="ds-text-title-m ds-font-bold ds-my-4">Highest career batting average in Tests</h1><div class="ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4"><div class="ds-p-0"><div><div class="ds-bg-fill-content-prime ds-py-3 ds-px-4 ds-flex ds-justify-between ds-items-center ds-gap-2"><div class="ds-text-title-xs ds-font-bold">Highest averages</div><div class="ds-flex ds-items-center ds-gap-4"><div class="ds-flex ds-flex-row ds-space-x-2"><div class="ds-popper-wrapper"><button class="ds-flex ds-items-center ds-justify-center ds-bg-transparent ds-border ds-border-ui-stroke ds-text-typo ds-rounded-full ds-h-8 ds-w-8 hover:ds-bg-ui-fill-hover focus:ds-ring-4 focus:ds-ring-button-tertiary ds-cursor-pointer" aria-expanded="false"><i class="icon-share-outlined ds-text-icon" style="font-size: 16px;"></i><span class="ds-text-tight-s ds-font-bold"></span></button></div><button class="ds-flex ds-items-center ds-justify-center ds-bg-transparent ds-border ds-border-ui-stroke ds-text-typo ds-rounded-full ds-h-8 ds-w-8 hover:ds-bg-ui-fill-hover focus:ds-ring-4 focus:ds-ring-button-tertiary"><i class="icon-link-filled ds-text-icon" style="font-size: 16px;"></i><span class="ds-text-tight-s ds-font-bold"></span></button></div></div></div><div class="ds-overflow-x-auto ds-scrollbar-hide"><table class="ds-w-full ds-table ds-table-xs ds-table-auto  ds-w-full ds-overflow-scroll ds-scrollbar-hide"><thead class="ds-bg-fill-content-alternate ds-text-left"><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">Player</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">Span</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">Mat</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">Inns</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">NO</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">Runs</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">HS</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><strong>Ave</strong></span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">BF</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">SR</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">100</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">50</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">0</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">4s</span></div></td><td class="ds-min-w-max ds-text-right"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false">6s</span></div></td></tr></thead><tbody class=""><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/donald-bradman-4188" title="DG Bradman (AUS)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DG Bradman (AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1928-1948</span></td><td class="ds-min-w-max ds-text-right"><span class="">52</span></td><td class="ds-min-w-max ds-text-right"><span class="">80</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="">6996</span></td><td class="ds-min-w-max ds-text-right"><span class="">334</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>99.94</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">9800+</span></td><td class="ds-min-w-max ds-text-right"><span class="">58.60</span></td><td class="ds-min-w-max ds-text-right"><span class="">29</span></td><td class="ds-min-w-max ds-text-right"><span class="">13</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">626+</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/adam-voges-8119" title="AC Voges (AUS)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">AC Voges (AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2015-2016</span></td><td class="ds-min-w-max ds-text-right"><span class="">20</span></td><td class="ds-min-w-max ds-text-right"><span class="">31</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="">1485</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">269*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>61.87</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">2667</span></td><td class="ds-min-w-max ds-text-right"><span class="">55.68</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="">186</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/graeme-pollock-46772" title="RG Pollock (SA)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">RG Pollock (SA)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1963-1970</span></td><td class="ds-min-w-max ds-text-right"><span class="">23</span></td><td class="ds-min-w-max ds-text-right"><span class="">41</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">2256</span></td><td class="ds-min-w-max ds-text-right"><span class="">274</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>60.97</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">1707+</span></td><td class="ds-min-w-max ds-text-right"><span class="">54.48</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">246+</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/george-headley-52050" title="GA Headley (WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">GA Headley (WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1930-1954</span></td><td class="ds-min-w-max ds-text-right"><span class="">22</span></td><td class="ds-min-w-max ds-text-right"><span class="">40</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">2190</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">270*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>60.83</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">416+</span></td><td class="ds-min-w-max ds-text-right"><span class="">56.00</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">104+</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/herbert-sutcliffe-20413" title="H Sutcliffe (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">H Sutcliffe (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1924-1935</span></td><td class="ds-min-w-max ds-text-right"><span class="">54</span></td><td class="ds-min-w-max ds-text-right"><span class="">84</span></td><td class="ds-min-w-max ds-text-right"><span class="">9</span></td><td class="ds-min-w-max ds-text-right"><span class="">4555</span></td><td class="ds-min-w-max ds-text-right"><span class="">194</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>60.73</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">6558+</span></td><td class="ds-min-w-max ds-text-right"><span class="">34.59</span></td><td class="ds-min-w-max ds-text-right"><span class="">16</span></td><td class="ds-min-w-max ds-text-right"><span class="">23</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">202+</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/eddie-paynter-18475" title="E Paynter (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">E Paynter (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1931-1939</span></td><td class="ds-min-w-max ds-text-right"><span class="">20</span></td><td class="ds-min-w-max ds-text-right"><span class="">31</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">1540</span></td><td class="ds-min-w-max ds-text-right"><span class="">243</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>59.23</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">1288+</span></td><td class="ds-min-w-max ds-text-right"><span class="">45.88</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">125+</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/ken-barrington-9014" title="KF Barrington (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">KF Barrington (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1955-1968</span></td><td class="ds-min-w-max ds-text-right"><span class="">82</span></td><td class="ds-min-w-max ds-text-right"><span class="">131</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">6806</span></td><td class="ds-min-w-max ds-text-right"><span class="">256</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>58.67</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">4957+</span></td><td class="ds-min-w-max ds-text-right"><span class="">42.42</span></td><td class="ds-min-w-max ds-text-right"><span class="">20</span></td><td class="ds-min-w-max ds-text-right"><span class="">35</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">591+</span></td><td class="ds-min-w-max ds-text-right"><span class="">27</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/everton-weekes-53241" title="ED Weekes (WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">ED Weekes (WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1948-1958</span></td><td class="ds-min-w-max ds-text-right"><span class="">48</span></td><td class="ds-min-w-max ds-text-right"><span class="">81</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">4455</span></td><td class="ds-min-w-max ds-text-right"><span class="">207</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>58.61</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">-</span></td><td class="ds-min-w-max ds-text-right"><span class="">0.00</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">19</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">258+</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/wally-hammond-14022" title="WR Hammond (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">WR Hammond (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1927-1947</span></td><td class="ds-min-w-max ds-text-right"><span class="">85</span></td><td class="ds-min-w-max ds-text-right"><span class="">140</span></td><td class="ds-min-w-max ds-text-right"><span class="">16</span></td><td class="ds-min-w-max ds-text-right"><span class="">7249</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">336*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>58.45</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">7491+</span></td><td class="ds-min-w-max ds-text-right"><span class="">38.07</span></td><td class="ds-min-w-max ds-text-right"><span class="">22</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">419+</span></td><td class="ds-min-w-max ds-text-right"><span class="">27</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/garry-sobers-52946" title="GS Sobers (WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">GS Sobers (WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1954-1974</span></td><td class="ds-min-w-max ds-text-right"><span class="">93</span></td><td class="ds-min-w-max ds-text-right"><span class="">160</span></td><td class="ds-min-w-max ds-text-right"><span class="">21</span></td><td class="ds-min-w-max ds-text-right"><span class="">8032</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">365*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>57.78</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">4063+</span></td><td class="ds-min-w-max ds-text-right"><span class="">53.58</span></td><td class="ds-min-w-max ds-text-right"><span class="">26</span></td><td class="ds-min-w-max ds-text-right"><span class="">30</span></td><td class="ds-min-w-max ds-text-right"><span class="">12</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">593+</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">32+</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/kumar-sangakkara-50710" title="KC Sangakkara (SL)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">KC Sangakkara (SL)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2000-2015</span></td><td class="ds-min-w-max ds-text-right"><span class="">134</span></td><td class="ds-min-w-max ds-text-right"><span class="">233</span></td><td class="ds-min-w-max ds-text-right"><span class="">17</span></td><td class="ds-min-w-max ds-text-right"><span class="">12400</span></td><td class="ds-min-w-max ds-text-right"><span class="">319</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>57.40</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="
span></td><td class="ds-min-w-max ds-text-right"><span class="">14</span></td><td class="ds-min-w-max ds-text-right"><span class="">20</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="">990</span></td><td class="ds-min-w-max ds-text-right"><span class="">122</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>55.00</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">178+</span></td><td class="ds-min-w-max ds-text-right"><span class="">29.21</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">37+</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/kane-williamson-277906" title="KS Williamson (NZ)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">KS Williamson (NZ)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2010-2024</span></td><td class="ds-min-w-max ds-text-right"><span class="">100</span></td><td class="ds-min-w-max ds-text-right"><span class="">176</span></td><td class="ds-min-w-max ds-text-right"><span class="">17</span></td><td class="ds-min-w-max ds-text-right"><span class="">8743</span></td><td class="ds-min-w-max ds-text-right"><span class="">251</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>54.98</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">17006</span></td><td class="ds-min-w-max ds-text-right"><span class="">51.41</span></td><td class="ds-min-w-max ds-text-right"><span class="">32</span></td><td class="ds-min-w-max ds-text-right"><span class="">34</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td><td class="ds-min-w-max ds-text-right"><span class="">971</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/charlie-davis-51641" title="CA Davis (WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">CA Davis (WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1968-1973</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">29</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">1301</span></td><td class="ds-min-w-max ds-text-right"><span class="">183</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>54.20</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">665+</span></td><td class="ds-min-w-max ds-text-right"><span class="">35.48</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">65+</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/vinod-kambli-30009" title="VG Kambli (IND)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">VG Kambli (IND)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1993-1995</span></td><td class="ds-min-w-max ds-text-right"><span class="">17</span></td><td class="ds-min-w-max ds-text-right"><span class="">21</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="">1084</span></td><td class="ds-min-w-max ds-text-right"><span class="">227</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>54.20</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">1823</span></td><td class="ds-min-w-max ds-text-right"><span class="">59.46</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td><td class="ds-min-w-max ds-text-right"><span class="">124</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/greg-chappell-4558" title="GS Chappell (AUS)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">GS Chappell (AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1970-1984</span></td><td class="ds-min-w-max ds-text-right"><span class="">87</span></td><td class="ds-min-w-max ds-text-right"><span class="">151</span></td><td class="ds-min-w-max ds-text-right"><span class="">19</span></td><td class="ds-min-w-max ds-text-right"><span class="">7110</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">247*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>53.86</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">13079+</span></td><td class="ds-min-w-max ds-text-right"><span class="">51.53</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td><td class="ds-min-w-max ds-text-right"><span class="">31</span></td><td class="ds-min-w-max ds-text-right"><span class="">12</span></td><td class="ds-min-w-max ds-text-right"><span class="">755</span></td><td class="ds-min-w-max ds-text-right"><span class="">16</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/dudley-nourse-46589" title="AD Nourse (SA)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">AD Nourse (SA)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1935-1951</span></td><td class="ds-min-w-max ds-text-right"><span class="">34</span></td><td class="ds-min-w-max ds-text-right"><span class="">62</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="">2960</span></td><td class="ds-min-w-max ds-text-right"><span class="">231</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>53.81</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">108+</span></td><td class="ds-min-w-max ds-text-right"><span class="">63.88</span></td><td class="ds-min-w-max ds-text-right"><span class="">9</span></td><td class="ds-min-w-max ds-text-right"><span class="">14</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">115+</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/sachin-tendulkar-35320" title="SR Tendulkar (IND)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">SR Tendulkar (IND)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1989-2013</span></td><td class="ds-min-w-max ds-text-right"><span class="">200</span></td><td class="ds-min-w-max ds-text-right"><span class="">329</span></td><td class="ds-min-w-max ds-text-right"><span class="">33</span></td><td class="ds-min-w-max ds-text-right"><span class="">15921</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">248*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>53.78</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">29437+</span></td><td class="ds-min-w-max ds-text-right"><span class="">54.04</span></td><td class="ds-min-w-max ds-text-right"><span class="">51</span></td><td class="ds-min-w-max ds-text-right"><span class="">68</span></td><td class="ds-min-w-max ds-text-right"><span class="">14</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">2058+</span></td><td class="ds-min-w-max ds-text-right"><span class="">69</span></td></tr><tr class="ds-bg-ui-fill-translucent"><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/harry-brook-911707" title="HC Brook (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">HC Brook (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2022-2024</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">18*</span></td><td class="ds-min-w-max ds-text-right"><span class="">30</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="">1558</span></td><td class="ds-min-w-max ds-text-right"><span class="">186</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>53.72</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">1795</span></td><td class="ds-min-w-max ds-text-right"><span class="">86.79</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">9</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="">181</span></td><td class="ds-min-w-max ds-text-right"><span class="">26</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/brian-lara-52337" title="BC Lara (ICC/WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">BC Lara (ICC/WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1990-2006</span></td><td class="ds-min-w-max ds-text-right"><span class="">131</span></td><td class="ds-min-w-max ds-text-right"><span class="">232</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="">11953</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">400*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>52.88</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">19753</span></td><td class="ds-min-w-max ds-text-right"><span class="">60.51</span></td><td class="ds-min-w-max ds-text-right"><span class="">34</span></td><td class="ds-min-w-max ds-text-right"><span class="">48</span></td><td class="ds-min-w-max ds-text-right"><span class="">17</span></td><td class="ds-min-w-max ds-text-right"><span class="">1559</span></td><td class="ds-min-w-max ds-text-right"><span class="">88</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/javed-miandad-40879" title="Javed Miandad (PAK)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Javed Miandad (PAK)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1976-1993</span></td><td class="ds-min-w-max ds-text-right"><span class="">124</span></td><td class="ds-min-w-max ds-text-right"><span class="">189</span></td><td class="ds-min-w-max ds-text-right"><span class="">21</span></td><td class="ds-min-w-max ds-text-right"><span class="">8832</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">280*</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>52.57</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">15164+</span></td><td class="ds-min-w-max ds-text-right"><span class="">45.99</span></td><td class="ds-min-w-max ds-text-right"><span class="">23</span></td><td class="ds-min-w-max ds-text-right"><span class="">43</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">788+</span></td><td class="ds-min-w-max ds-text-right"><span class="">48</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/rahul-dravid-28114" title="R Dravid (ICC/IND)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">R Dravid (ICC/IND)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1996-2012</span></td><td class="ds-min-w-max ds-text-right"><span class="">164</span></td><td class="ds-min-w-max ds-text-right"><span class="">286</span></td><td class="ds-min-w-max ds-text-right"><span class="">32</span></td><td class="ds-min-w-max ds-text-right"><span class="">13288</span></td><td class="ds-min-w-max ds-text-right"><span class="">270</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>52.31</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">31258</span></td><td class="ds-min-w-max ds-text-right"><span class="">42.51</span></td><td class="ds-min-w-max ds-text-right"><span class="">36</span></td><td class="ds-min-w-max ds-text-right"><span class="">63</span></td><td class="ds-min-w-max ds-text-right"><span class="">8</span></td><td class="ds-min-w-max ds-text-right"><span class="">1654</span></td><td class="ds-min-w-max ds-text-right"><span class="">21</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/mohammad-yousuf-43650" title="Mohammad Yousuf (PAK)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Mohammad Yousuf (PAK)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1998-2010</span></td><td class="ds-min-w-max ds-text-right"><span class="">90</span></td><td class="ds-min-w-max ds-text-right"><span class="">156</span></td><td class="ds-min-w-max ds-text-right"><span class="">12</span></td><td class="ds-min-w-max ds-text-right"><span class="">7530</span></td><td class="ds-min-w-max ds-text-right"><span class="">223</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>52.29</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">14372</span></td><td class="ds-min-w-max ds-text-right"><span class="">52.39</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td><td class="ds-min-w-max ds-text-right"><span class="">33</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td><td class="ds-min-w-max ds-text-right"><span class="">957</span></td><td class="ds-min-w-max ds-text-right"><span class="">51</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/younis-khan-43652" title="Younis Khan (PAK)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Younis Khan (PAK)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2000-2017</span></td><td class="ds-min-w-max ds-text-right"><span class="">118</span></td><td class="ds-min-w-max ds-text-right"><span class="">213</span></td><td class="ds-min-w-max ds-text-right"><span class="">19</span></td><td class="ds-min-w-max ds-text-right"><span class="">10099</span></td><td class="ds-min-w-max ds-text-right"><span class="">313</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>52.05</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="
AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1978-1994</span></td><td class="ds-min-w-max ds-text-right"><span class="">156</span></td><td class="ds-min-w-max ds-text-right"><span class="">265</span></td><td class="ds-min-w-max ds-text-right"><span class="">44</span></td><td class="ds-min-w-max ds-text-right"><span class="">11174</span></td><td class="ds-min-w-max ds-text-right"><span class="">205</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>50.56</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">27002+</span></td><td class="ds-min-w-max ds-text-right"><span class="">41.09</span></td><td class="ds-min-w-max ds-text-right"><span class="">27</span></td><td class="ds-min-w-max ds-text-right"><span class="">63</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td><td class="ds-min-w-max ds-text-right"><span class="">1161</span></td><td class="ds-min-w-max ds-text-right"><span class="">28</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/daryl-mitchell-381743" title="DJ Mitchell (NZ)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DJ Mitchell (NZ)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">2019-2024</span></td><td class="ds-min-w-max ds-text-right"><span class="">23</span></td><td class="ds-min-w-max ds-text-right"><span class="">37</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">1608</span></td><td class="ds-min-w-max ds-text-right"><span class="">190</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>50.25</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">3014</span></td><td class="ds-min-w-max ds-text-right"><span class="">53.35</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="">158</span></td><td class="ds-min-w-max ds-text-right"><span class="">29</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/viv-richards-52812" title="IVA Richards (WI)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">IVA Richards (WI)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1974-1991</span></td><td class="ds-min-w-max ds-text-right"><span class="">121</span></td><td class="ds-min-w-max ds-text-right"><span class="">182</span></td><td class="ds-min-w-max ds-text-right"><span class="">12</span></td><td class="ds-min-w-max ds-text-right"><span class="">8540</span></td><td class="ds-min-w-max ds-text-right"><span class="">291</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>50.23</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">9613+</span></td><td class="ds-min-w-max ds-text-right"><span class="">69.77</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td><td class="ds-min-w-max ds-text-right"><span class="">45</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">952+</span></td><td class="ds-min-w-max ds-text-right"><span class="">84</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/denis-compton-10777" title="DCS Compton (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DCS Compton (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1937-1957</span></td><td class="ds-min-w-max ds-text-right"><span class="">78</span></td><td class="ds-min-w-max ds-text-right"><span class="">131</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">5807</span></td><td class="ds-min-w-max ds-text-right"><span class="">278</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>50.06</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">2731+</span></td><td class="ds-min-w-max ds-text-right"><span class="">38.81</span></td><td class="ds-min-w-max ds-text-right"><span class="">17</span></td><td class="ds-min-w-max ds-text-right"><span class="">28</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">342+</span></td><td class="ds-min-w-max ds-text-right"><span class="">3</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/mahela-jayawardene-49289" title="DPMD Jayawardene (SL)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DPMD Jayawardene (SL)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1997-2014</span></td><td class="ds-min-w-max ds-text-right"><span class="">149</span></td><td class="ds-min-w-max ds-text-right"><span class="">252</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">11814</span></td><td class="ds-min-w-max ds-text-right"><span class="">374</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>49.84</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">22959</span></td><td class="ds-min-w-max ds-text-right"><span class="">51.45</span></td><td class="ds-min-w-max ds-text-right"><span class="">34</span></td><td class="ds-min-w-max ds-text-right"><span class="">50</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="">1387</span></td><td class="ds-min-w-max ds-text-right"><span class="">61</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/inzamam-ul-haq-40570" title="Inzamam-ul-Haq (ICC/PAK)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Inzamam-ul-Haq (ICC/PAK)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1992-2007</span></td><td class="ds-min-w-max ds-text-right"><span class="">120</span></td><td class="ds-min-w-max ds-text-right"><span class="">200</span></td><td class="ds-min-w-max ds-text-right"><span class="">22</span></td><td class="ds-min-w-max ds-text-right"><span class="">8830</span></td><td class="ds-min-w-max ds-text-right"><span class="">329</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>49.60</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">16345</span></td><td class="ds-min-w-max ds-text-right"><span class="">54.02</span></td><td class="ds-min-w-max ds-text-right"><span class="">25</span></td><td class="ds-min-w-max ds-text-right"><span class="">46</span></td><td class="ds-min-w-max ds-text-right"><span class="">15</span></td><td class="ds-min-w-max ds-text-right"><span class="
span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>48.25</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="">15525</span></td><td class="ds-min-w-max ds-text-right"><span class="">59.67</span></td><td class="ds-min-w-max ds-text-right"><span class="">27</span></td><td class="ds-min-w-max ds-text-right"><span class="">38</span></td><td class="ds-min-w-max ds-text-right"><span class="">11</span></td><td class="ds-min-w-max ds-text-right"><span class="">1165</span></td><td class="ds-min-w-max ds-text-right"><span class="">24</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/bill-ponsford-7131" title="WH Ponsford (AUS)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">WH Ponsford (AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1924-1934</span></td><td class="ds-min-w-max ds-text-right"><span class="">29</span></td><td class="ds-min-w-max ds-text-right"><span class="">48</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="">2122</span></td><td class="ds-min-w-max ds-text-right"><span class="">266</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>48.22</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">3118+</span></td><td class="ds-min-w-max ds-text-right"><span class="">44.77</span></td><td class="ds-min-w-max ds-text-right"><span class="">7</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">119+</span></td><td class="ds-min-w-max ds-text-right"><span class="">0</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/stan-mccabe-6540" title="SJ McCabe (AUS)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">SJ McCabe (AUS)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1930-1938</span></td><td class="ds-min-w-max ds-text-right"><span class="">39</span></td><td class="ds-min-w-max ds-text-right"><span class="">62</span></td><td class="ds-min-w-max ds-text-right"><span class="">5</span></td><td class="ds-min-w-max ds-text-right"><span class="">2748</span></td><td class="ds-min-w-max ds-text-right"><span class="">232</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>48.21</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">3217+</span></td><td class="ds-min-w-max ds-text-right"><span class="">60.02</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="">13</span></td><td class="ds-min-w-max ds-text-right"><span class="">4</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">241+</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">5+</span></td></tr><tr class=""><td class="ds-min-w-max"><div class="ds-popper-wrapper"><span class="ds-cursor-pointer" aria-expanded="false"><a href="/cricketers/douglas-jardine-15481" title="DR Jardine (ENG)" class="ds-inline-flex ds-items-start ds-leading-none"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">DR Jardine (ENG)</span></a></span></div></td><td class="ds-min-w-max ds-text-right"><span class="">1928-1934</span></td><td class="ds-min-w-max ds-text-right"><span class="">22</span></td><td class="ds-min-w-max ds-text-right"><span class="">33</span></td><td class="ds-min-w-max ds-text-right"><span class="">6</span></td><td class="ds-min-w-max ds-text-right"><span class="">1296</span></td><td class="ds-min-w-max ds-text-right"><span class="">127</span></td><td class="ds-min-w-max ds-text-right"><span class=""><strong>48.00</strong></span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">2110+</span></td><td class="ds-min-w-max ds-text-right"><span class="">25.59</span></td><td class="ds-min-w-max ds-text-right"><span class="">1</span></td><td class="ds-min-w-max ds-text-right"><span class="">10</span></td><td class="ds-min-w-max ds-text-right"><span class="">2</span></td><td class="ds-min-w-max ds-text-right"><span class="ds-relative ds--right-1.5">53+</span></td><td class="ds-min-w-max ds-text-right"><span class="">0</span></td></tr></tbody></table></div></div><div><div><div class="ds-text-tight-s ds-font-regular ds-flex ds-p-4"><span class="ds-mr-2">Adjust:</span><strong class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">Most recent</strong><span class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">Past week</span><span class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">Past Month</span><span class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">Past year</span><span class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">4 years</span><span class="ds-cursor-pointer ds-pr-2 ds-mr-2 ds-border-r ds-border-ui-stroke">10 years</span><span class="ds-cursor-pointer ds-pr-2 ds-mr-2">25 years</span></div></div></div></div></div><div class="ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4"><div class="ds-p-4"><div class="ds-text-tight-s ds-font-regular ds-italic"><span>Minimum of 20 innings</span></div></div></div><div class="ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4 ci-record-footnote"><div class="ds-p-4"><div class="ds-text-tight-s ds-font-bold ds-mb-2">Records includes the following current or recent matches:</div><div class="ds-text-tight-s ds-font-regular ds-mb-1"><p>England vs Sri Lanka at The Oval, Sri Lanka in England 3rd Test, Sep 6-10, 2024 [<a href="/series/sri-lanka-in-england-2024-1385672/england-vs-sri-lanka-3rd-test-1385696/full-scorecard"><u>Test # 2548 - Live]</u></a><br> &gt;&gt;  94/1 (15.0 ov,  BKG Mendis 30*,  P Nissanka 53*,  Shoaib Bashir 0/7) - Stumps</p></div><div class="ds-text-tight-s ds-font-regular ds-mb-1"><p>Pakistan vs Bangladesh at Rawalpindi, Bangladesh in Pakistan 2nd Test, Aug 30-Sep 3, 2024 [<a href="/series/bangladesh-in-pakistan-2024-1442203/pakistan-vs-bangladesh-2nd-test-1442214/full-scorecard"><u>Test # 2547]</u></a></p></div><div class="ds-text-tight-s ds-font-regular ds-mb-1"><p>England vs Sri Lanka at Lord's, Sri Lanka in England 2nd Test, Aug 29-Sep 1, 2024 [<a href="/series/sri-lanka-in-england-2024-1385672/england-vs-sri-lanka-2nd-test-1385695/full-scorecard"><u>Test # 2546]</u></a></p></div></div></div></div>

# %%
soup.find_all('table')
# Out:
# [<table class="ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide">
#  <thead class="ds-bg-fill-content-alternate ds-text-left">
#  <tr class="">
#  <td class="ds-min-w-max">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Player
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Span
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Mat
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Inns
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
# ...

# %%
soup.find('table', class_ = "ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide")
# Out:
# <table class="ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide">
# <thead class="ds-bg-fill-content-alternate ds-text-left">
# <tr class="">
# <td class="ds-min-w-max">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Player
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Span
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Mat
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Inns
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# ...

# %%
table = soup.find('table', class_ = "ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide")

# %%
print(table)
# Out:
# <table class="ds-w-full ds-table ds-table-xs ds-table-auto ds-w-full ds-overflow-scroll ds-scrollbar-hide">
# <thead class="ds-bg-fill-content-alternate ds-text-left">
# <tr class="">
# <td class="ds-min-w-max">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Player
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Span
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Mat
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# <span class="ds-cursor-pointer">
#                    Inns
#                   </span>
# </div>
# </td>
# <td class="ds-min-w-max ds-text-right">
# <div class="ds-popper-wrapper">
# ...

# %%
world_titles = table.find_all('span')

# %%
world_titles
# Out:
# [<span class="ds-cursor-pointer">
#                     Player
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     Span
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     Mat
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     Inns
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     NO
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     Runs
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     HS
#                    </span>,
#  <span class="ds-cursor-pointer">
#  <strong>
#                      Ave
#                     </strong>
#  </span>,
#  <span class="ds-cursor-pointer">
#                     BF
#                    </span>,
#  <span class="ds-cursor-pointer">
#                     SR
#                    </span>,
#  <span class="ds-cursor-pointer">
# ...

# %%
world_table_titles = [title.text.strip() for title in world_titles[0:15]]

# %%
print(world_table_titles)
# Out:
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, NO, Runs, HS, Ave, BF, SR, 100, 50, 0, 4s, 6s]
# Index: []

# %%
table.find_all('tr')
# Out:
# [<tr class="">
#  <td class="ds-min-w-max">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Player
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Span
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Mat
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     Inns
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
#  <div class="ds-popper-wrapper">
#  <span class="ds-cursor-pointer">
#                     NO
#                    </span>
#  </div>
#  </td>
#  <td class="ds-min-w-max ds-text-right">
# ...

# %%
 column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_raw_data = [data.text.strip() for data in row_data]
    print(individual_raw_data)


    length = len(df)
    df.loc[length] = individual_raw_data
# Out:
# ['DG Bradman (AUS)', '1928-1948', '52', '80', '10', '6996', '334', '99.94', '9800+', '58.60', '29', '13', '7', '626+', '6']
# ['AC Voges (AUS)', '2015-2016', '20', '31', '7', '1485', '269*', '61.87', '2667', '55.68', '5', '4', '2', '186', '5']
# ['RG Pollock (SA)', '1963-1970', '23', '41', '4', '2256', '274', '60.97', '1707+', '54.48', '7', '11', '1', '246+', '11']
# ['GA Headley (WI)', '1930-1954', '22', '40', '4', '2190', '270*', '60.83', '416+', '56.00', '10', '5', '2', '104+', '1']
# ['H Sutcliffe (ENG)', '1924-1935', '54', '84', '9', '4555', '194', '60.73', '6558+', '34.59', '16', '23', '2', '202+', '6']
# ['E Paynter (ENG)', '1931-1939', '20', '31', '5', '1540', '243', '59.23', '1288+', '45.88', '4', '7', '3', '125+', '4']
# ['KF Barrington (ENG)', '1955-1968', '82', '131', '15', '6806', '256', '58.67', '4957+', '42.42', '20', '35', '5', '591+', '27']
# ['ED Weekes (WI)', '1948-1958', '48', '81', '5', '4455', '207', '58.61', '-', '0.00', '15', '19', '6', '258+', '2']
# ...

# %%
df
# Out:
#                 Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 0     DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 1       AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 2      RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 3      GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# 4    H Sutcliffe (ENG)  1924-1935   54   84   9  4555   194  60.73  6558+
# ..                 ...        ...  ...  ...  ..   ...   ...    ...    ...
# 121   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 122  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 123  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 124    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 125   DR Jardine (ENG)  1928-1934   22   33   6  1296   127  48.00  2110+
#
#         SR 100  50   0    4s  6s
# 0    58.60  29  13   7  626+   6
# ...

# %%
df.to_csv(r'C:\Users\Hp\Desktop\cricket BeautifulSoup\PlayersData.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv(r'TestPlayersData.csv')

# %%
df
# Out:
#                 Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0     DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1       AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2      RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                 ...        ...  ...   ...  ..   ...   ...    ...    ...
# 125   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 126  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 127  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 128    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 129   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#         SR  100  50   0    4s  6s
# ...

# %%
df.index = range (1, len(df) +1)

# %%
df
# Out:
#                 Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 1     DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 2       AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3      RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 5      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                 ...        ...  ...   ...  ..   ...   ...    ...    ...
# 126   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 127  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 128  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 129    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 130   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#         SR  100  50   0    4s  6s
# ...

# %% [markdown]
# **Renaming Multiple Columns in a list**

# %%
df = df.rename(columns = {'Mat':'Matches','NO':'Not_Outs' , 'HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df1.head()
# Out:
#               Player       Span Matches  Inns  Not_Outs  Runs  \
# 1   DG Bradman (AUS)  1928-1948      52    80        10  6996
# 2     AC Voges (AUS)  2015-2016      20    31         7  1485
# 3    RG Pollock (SA)  1963-1970      23    41         4  2256
# 4    GA Headley (WI)  1930-1954      22    40         4  2190
# 6  H Sutcliffe (ENG)  1924-1935      54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 1                334  99.94       9800+                58.60   29  13  7
# 2               269*  61.87        2667                55.68    5   4  2
# 3                274  60.97       1707+                54.48    7  11  1
# 4               270*  60.83        416+                56.00   10   5  2
# 6                194  60.73       6558+                34.59   16  23  2
#
#      4s  6s
# 1  626+   6
# 2   186   5
# 3  246+  11
# 4  104+   1
# 6  202+   6

# %% [markdown]
# **Checking Null Values**

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                    Player       Span Matches  Inns  Not_Outs  Runs  \
# 9          ED Weekes (WI)  1948-1958      48    81         5  4455
# 17        CL Walcott (WI)  1948-1960      44    74         7  3798
# 60   Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415
# 75         ED Weekes (WI)  1948-1958      48    81         5  4455
# 81        CL Walcott (WI)  1948-1960      44    74         7  3798
# 123  Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415
#
#     Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                  207  58.61         NaN                  NaN   15  19  6
# 17                 220  56.68         NaN                  NaN   15  14  1
# 60                144*  48.79         NaN                  NaN    5   6  3
# 75                 207  58.61         NaN                  NaN   15  19  6
# 81                 220  56.68         NaN                  NaN   15  14  1
# ...

# %%
 df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
# Out:
#             Player       Span Matches  Inns  Not_Outs  Runs  \
# 9   ED Weekes (WI)  1948-1958      48    81         5  4455
# 75  ED Weekes (WI)  1948-1958      48    81         5  4455
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61           0                  0.0   15  19  6
# 75                207  58.61           0                  0.0   15  19  6
#
#       4s 6s
# 9   258+  2
# 75  258+  2

# %%
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span Matches  Inns  Not_Outs  Runs  \
# 17  CL Walcott (WI)  1948-1960      44    74         7  3798
# 81  CL Walcott (WI)  1948-1960      44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 17                220  56.68           0                  0.0   15  14  1
# 81                220  56.68           0                  0.0   15  14  1
#
#       4s  6s
# 17  107+  11
# 81  107+  11

# %% [markdown]
# **Droping Duplicates**

# %%
 df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 126     True
# 127     True
# 128     True
# 129     True
# 130     True
# Length: 130, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                 Player       Span Matches  Inns  Not_Outs  Runs  \
# 5      GA Headley (WI)  1930-1954      22    40         4  2190
# 12      GS Sobers (WI)  1954-1974      93   160        21  8032
# 16      JB Hobbs (ENG)  1908-1930      61   102         7  5410
# 56       V Kohli (IND)  2011-2024     113   191        11  8848
# 68    DG Bradman (AUS)  1928-1948      52    80        10  6996
# ..                 ...        ...     ...   ...       ...   ...
# 126   KD Walters (AUS)  1965-1981      74   125        14  5357
# 127  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 128  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 129    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 130   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#     Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 5                 270*  60.83        416+                56.00   10   5   2
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs  \
# 1    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     RG Pollock (SA)  1963-1970      23    41         4  2256
# 4     GA Headley (WI)  1930-1954      22    40         4  2190
# 6   H Sutcliffe (ENG)  1924-1935      54    84         9  4555
# ..                ...        ...     ...   ...       ...   ...
# 63   KD Walters (AUS)  1965-1981      74   125        14  5357
# 64  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 65  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 66    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 67   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 1                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df # hence you can see there is no duplicate values.
# Out:
#                       Player       Span Matches  Inns  Not_Outs   Runs  \
# 1           DG Bradman (AUS)  1928-1948      52    80        10   6996
# 2             AC Voges (AUS)  2015-2016      20    31         7   1485
# 3            RG Pollock (SA)  1963-1970      23    41         4   2256
# 4            GA Headley (WI)  1930-1954      22    40         4   2190
# 6          H Sutcliffe (ENG)  1924-1935      54    84         9   4555
# 7            E Paynter (ENG)  1931-1939      20    31         5   1540
# 8        KF Barrington (ENG)  1955-1968      82   131        15   6806
# 9             ED Weekes (WI)  1948-1958      48    81         5   4455
# 10          WR Hammond (ENG)  1927-1947      85   140        16   7249
# 11            GS Sobers (WI)  1954-1974      93   160        21   8032
# 13        KC Sangakkara (SL)  2000-2015     134   233        17  12400
# 14           SPD Smith (AUS)  2010-2024     109   195        25   9685
# ...

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %% [markdown]
# **Spliting up Span into Start and End Date**

# %%
df['Span']
# Out:
# 1     1928-1948
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
# 6     1924-1935
#         ...
# 63    1965-1981
# 64    2002-2014
# 65    1924-1934
# 66    1930-1938
# 67    1928-1934
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-')
# Out:
# 1     [1928, 1948]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 6     [1924, 1935]
#           ...
# 63    [1965, 1981]
# 64    [2002, 2014]
# 65    [1924, 1934]
# 66    [1930, 1938]
# 67    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 1     1948
# 2     2016
# 3     1970
# 4     1954
# 6     1935
#       ...
# 63    1981
# 64    2014
# 65    1934
# 66    1938
# 67    1934
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs  \
# 1    DG Bradman (AUS)  1928-1948      52    80        10  6996
# 2      AC Voges (AUS)  2015-2016      20    31         7  1485
# 3     RG Pollock (SA)  1963-1970      23    41         4  2256
# 4     GA Headley (WI)  1930-1954      22    40         4  2190
# 6   H Sutcliffe (ENG)  1924-1935      54    84         9  4555
# ..                ...        ...     ...   ...       ...   ...
# 63   KD Walters (AUS)  1965-1981      74   125        14  5357
# 64  GC Smith (ICC/SA)  2002-2014     117   205        13  9265
# 65  WH Ponsford (AUS)  1924-1934      29    48         4  2122
# 66    SJ McCabe (AUS)  1930-1938      39    62         5  2748
# 67   DR Jardine (ENG)  1928-1934      22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 1                 334  99.94       9800+                58.60   29  13   7
# ...

# %% [markdown]
# **Droping Span Column**

# %%
df.drop(['Span'],axis = 1)
# Out:
#                Player Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 1    DG Bradman (AUS)      52    80        10  6996                334  99.94
# 2      AC Voges (AUS)      20    31         7  1485               269*  61.87
# 3     RG Pollock (SA)      23    41         4  2256                274  60.97
# 4     GA Headley (WI)      22    40         4  2190               270*  60.83
# 6   H Sutcliffe (ENG)      54    84         9  4555                194  60.73
# ..                ...     ...   ...       ...   ...                ...    ...
# 63   KD Walters (AUS)      74   125        14  5357                250  48.26
# 64  GC Smith (ICC/SA)     117   205        13  9265                277  48.25
# 65  WH Ponsford (AUS)      29    48         4  2122                266  48.22
# 66    SJ McCabe (AUS)      39    62         5  2748                232  48.21
# 67   DR Jardine (ENG)      22    33         6  1296                127  48.00
#
# ...

# %%
df.head()
# Out:
#               Player       Span Matches  Inns  Not_Outs  Runs  \
# 1   DG Bradman (AUS)  1928-1948      52    80        10  6996
# 2     AC Voges (AUS)  2015-2016      20    31         7  1485
# 3    RG Pollock (SA)  1963-1970      23    41         4  2256
# 4    GA Headley (WI)  1930-1954      22    40         4  2190
# 6  H Sutcliffe (ENG)  1924-1935      54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 1                334  99.94       9800+                58.60   29  13  7
# 2               269*  61.87        2667                55.68    5   4  2
# 3                274  60.97       1707+                54.48    7  11  1
# 4               270*  60.83        416+                56.00   10   5  2
# 6                194  60.73       6558+                34.59   16  23  2
#
#      4s  6s Rookie_Year Final_Year
# 1  626+   6        1928       1948
# 2   186   5        2015       2016
# 3  246+  11        1963       1970
# ...

# %% [markdown]
# **Spliting the Column from the Country**

# %%
df['Player'].str.split(pat = '(')
# Out:
# 1      [DG Bradman , AUS)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
# 6     [H Sutcliffe , ENG)]
#               ...
# 63     [KD Walters , AUS)]
# 64    [GC Smith , ICC/SA)]
# 65    [WH Ponsford , AUS)]
# 66      [SJ McCabe , AUS)]
# 67     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df["Country"] = df["Player"].str.split(pat ="(").str[1]

# %%
df["Country"]
# Out:
# 1        AUS)
# 2        AUS)
# 3         SA)
# 4         WI)
# 6        ENG)
#        ...
# 63       AUS)
# 64    ICC/SA)
# 65       AUS)
# 66       AUS)
# 67       ENG)
# Name: Country, Length: 63, dtype: object

# %%
df["Country"]=df["Country"].str.split(pat = ")").str[0]

# %%
df["Country"]
# Out:
# 1        AUS
# 2        AUS
# 3         SA
# 4         WI
# 6        ENG
#        ...
# 63       AUS
# 64    ICC/SA
# 65       AUS
# 66       AUS
# 67       ENG
# Name: Country, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#          Player       Span Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 1   DG Bradman   1928-1948      52    80        10  6996                334
# 2     AC Voges   2015-2016      20    31         7  1485               269*
# 3   RG Pollock   1963-1970      23    41         4  2256                274
# 4   GA Headley   1930-1954      22    40         4  2190               270*
# 6  H Sutcliffe   1924-1935      54    84         9  4555                194
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 1  99.94       9800+                58.60   29  13  7  626+   6        1928
# 2  61.87        2667                55.68    5   4  2   186   5        2015
# 3  60.97       1707+                54.48    7  11  1  246+  11        1963
# 4  60.83        416+                56.00   10   5  2  104+   1        1930
# 6  60.73       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year Country
# 1       1948     AUS
# ...

# %% [markdown]
# **Spliting Higest_inns_Score to remove"*"**

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 1     334
# 2     269
# 3     274
# 4     270
# 6     194
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score']
# Out:
# 1     334
# 2     269
# 3     274
# 4     270
# 6     194
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %% [markdown]
# **Change Datatypes**

# %%
df.dtypes
# Out:
# Player                  object
# Span                    object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 1     334
# 2     269
# 3     274
# 4     270
# 6     194
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 63, dtype: int32

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df['Highest_Inns_Score']
# Out:
# 1     334
# 2     269
# 3     274
# 4     270
# 6     194
#      ...
# 63    250
# 64    277
# 65    266
# 66    232
# 67    127
# Name: Highest_Inns_Score, Length: 63, dtype: int32

# %%
df = df.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Span                    object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Matches'] = df['Matches'].str.split(pat = '*').str[0]

# %%
df['Matches'] = df['Matches'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Span                    object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9        ED Weekes   1948-1958       48    81         5  4455
# 17      CL Walcott   1948-1960       44    74         7  3798
# 60  Hon.FS Jackson   1893-1905       20    33         4  1415
#
#     Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                  207  58.61         NaN                  0.0   15  19  6
# 17                 220  56.68         NaN                  0.0   15  14  1
# 60                 144  48.79         NaN                  0.0    5   6  3
#
#       4s  6s  Rookie_Year  Final_Year Country
# 9   258+   2         1948        1958      WI
# 17  107+  11         1948        1960      WI
# 60   51+   0         1893        1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Span                    object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs   Runs  \
# 1         DG Bradman   1928-1948       52    80        10   6996
# 2           AC Voges   2015-2016       20    31         7   1485
# 3         RG Pollock   1963-1970       23    41         4   2256
# 4         GA Headley   1930-1954       22    40         4   2190
# 6        H Sutcliffe   1924-1935       54    84         9   4555
# 7          E Paynter   1931-1939       20    31         5   1540
# 8      KF Barrington   1955-1968       82   131        15   6806
# 9          ED Weekes   1948-1958       48    81         5   4455
# 10        WR Hammond   1927-1947       85   140        16   7249
# 11         GS Sobers   1954-1974       93   160        21   8032
# 13     KC Sangakkara   2000-2015      134   233        17  12400
# 14         SPD Smith   2010-2024      109   195        25   9685
# 15          JB Hobbs   1908-1930       61   102         7   5410
# ...

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs   Runs  \
# 1         DG Bradman   1928-1948       52    80        10   6996
# 2           AC Voges   2015-2016       20    31         7   1485
# 3         RG Pollock   1963-1970       23    41         4   2256
# 4         GA Headley   1930-1954       22    40         4   2190
# 6        H Sutcliffe   1924-1935       54    84         9   4555
# 7          E Paynter   1931-1939       20    31         5   1540
# 8      KF Barrington   1955-1968       82   131        15   6806
# 9          ED Weekes   1948-1958       48    81         5   4455
# 10        WR Hammond   1927-1947       85   140        16   7249
# 11         GS Sobers   1954-1974       93   160        21   8032
# 13     KC Sangakkara   2000-2015      134   233        17  12400
# 14         SPD Smith   2010-2024      109   195        25   9685
# 15          JB Hobbs   1908-1930       61   102         7   5410
# ...

# %%
df = df.astype({'4s':'int','6s':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Span                    object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %% [markdown]
# **Building out Carrer_Length Column**

# %%
df['Carrer_Length'] = df['Final_Year']-df['Rookie_Year']

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs   Runs  \
# 1         DG Bradman   1928-1948       52    80        10   6996
# 2           AC Voges   2015-2016       20    31         7   1485
# 3         RG Pollock   1963-1970       23    41         4   2256
# 4         GA Headley   1930-1954       22    40         4   2190
# 6        H Sutcliffe   1924-1935       54    84         9   4555
# 7          E Paynter   1931-1939       20    31         5   1540
# 8      KF Barrington   1955-1968       82   131        15   6806
# 9          ED Weekes   1948-1958       48    81         5   4455
# 10        WR Hammond   1927-1947       85   140        16   7249
# 11         GS Sobers   1954-1974       93   160        21   8032
# 13     KC Sangakkara   2000-2015      134   233        17  12400
# 14         SPD Smith   2010-2024      109   195        25   9685
# 15          JB Hobbs   1908-1930       61   102         7   5410
# ...

# %% [markdown]
# ***Calculating Average Carrer Length***

# %%
df['Carrer_Length'].mean()
# Out:
# 13.031746031746032

# %% [markdown]
# ***Avg Batting_Strike_Rate for Cricketers who Played over 10 Years***

# %%
df[df['Carrer_Length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95590909090909

# %% [markdown]
# ***Finding Number of Crickers Played before 1960***

# %%
df[df['Rookie_Year'] < 1960]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 1       DG Bradman   1928-1948       52    80        10  6996
# 4       GA Headley   1930-1954       22    40         4  2190
# 6      H Sutcliffe   1924-1935       54    84         9  4555
# 7        E Paynter   1931-1939       20    31         5  1540
# 8    KF Barrington   1955-1968       82   131        15  6806
# 9        ED Weekes   1948-1958       48    81         5  4455
# 10      WR Hammond   1927-1947       85   140        16  7249
# 11       GS Sobers   1954-1974       93   160        21  8032
# 15        JB Hobbs   1908-1930       61   102         7  5410
# 17      CL Walcott   1948-1960       44    74         7  3798
# 18        L Hutton   1937-1955       79   138        15  6971
# 21    GE Tyldesley   1921-1929       14    20         2   990
# 26       AD Nourse   1935-1951       34    62         7  2960
# 35         J Ryder   1920-1929       20    32         5  1394
# ...

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 23

# %% [markdown]
# ***Max Highest Inns score by Country***

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int32

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highest_innings_Country').reset_index().sort_values('Highest_innings_Country',ascending = False)
# Out:
#     Country  Highest_innings_Country
# 5    ICC/WI                      400
# 0       AUS                      380
# 10       SL                      374
# 11       WI                      365
# 1       ENG                      364
# 3   ICC/PAK                      329
# 2   ICC/IND                      319
# 8       PAK                      313
# 9        SA                      278
# 4    ICC/SA                      277
# 6       IND                      254
# 7        NZ                      251
# 12      ZIM                      232

# %% [markdown]
# ***100rds , 50s , ducks(0) Avg by Country***

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.692308  21.230769   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      17.600000  23.600000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
